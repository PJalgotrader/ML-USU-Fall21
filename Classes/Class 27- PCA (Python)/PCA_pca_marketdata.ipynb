# %% [markdown]
# <img src="logo.jpg" />
#
# ## [Prof. Pedram Jahangiry](https://huntsman.usu.edu/directory/jahangiry-pedram)
# [GitHub account](https://github.com/PJalgotrader)
#
# [YouTube Channel](https://www.youtube.com/channel/UCNDElcuuyX-2pSatVBDpJJQ/playlists)

# %% [markdown]
# # Unsupervised Learning: Principle Component Analysis (PCA)
#
# ## Using pca package
# pca is a python package to perform Principal Component Analysis and to create insightful plots. The core of PCA is build on sklearn functionality to find maximum compatibility when combining with other packages.
#
# for **installation**:
# pip install pca

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()  #if you want to use seaborn themes with matplotlib functions
import warnings
warnings.filterwarnings('ignore')

# %%
rand_state= 1000

# %%
from pca import pca

# %%
pca()

# %%
df = pd.read_csv('market_data.csv')
df.head()
# Out:
#    stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 0        72  1/31/2018          0.86         0.85         0.86
# 1        78  1/31/2018          0.66         0.67         0.66
# 2       465  1/31/2018          0.57         0.65         0.64
# 3       486  1/31/2018          0.48         0.52         0.50
# 4       552  1/31/2018          0.88         0.87         0.87
#
#    Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  Total_Capital  \
# 0            0.90    0.84  0.01         0.17         0.09  ...           0.54
# 1            0.37    0.92  0.01         0.25         0.58  ...           0.27
# 2            0.71    0.18  0.01         0.35         0.46  ...           0.18
# 3            0.36    0.30  0.01         0.81         0.81  ...           0.70
# 4            0.88    0.75  0.01         0.81         0.77  ...           0.64
#
#    Total_Debt  Total_Debt_Capital  Total_Liabilities_Total_Assets  Vol1Y_Usd  \
# 0        0.85                1.00                            0.99       0.22
# 1        0.65                1.00                            1.00       0.04
# 2        0.61                1.00                            1.00       0.99
# 3        0.85                0.99                            0.99       0.96
# 4        0.81                0.99                            0.99       0.92
#
#    Vol3Y_Usd  R1M_Usd  R3M_Usd  R6M_Usd  R12M_Usd
# 0       0.83   -0.022   -0.078    0.001     0.000
# 1       0.17    0.006    0.047    0.264     0.000
# 2       1.00    0.033    0.095    0.393    -0.502
# 3       0.98   -0.139    0.146    0.030    -0.463
# 4       0.74   -0.044   -0.307   -0.349    -0.403
#
# [5 rows x 99 columns]

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4450 entries, 0 to 4450
# Data columns (total 99 columns):
# stock_id                          4450 non-null int64
# date                              4450 non-null object
# Advt_12M_Usd                      4450 non-null float64
# Advt_3M_Usd                       4450 non-null float64
# Advt_6M_Usd                       4450 non-null float64
# Asset_Turnover                    4450 non-null float64
# Bb_Yld                            4450 non-null float64
# Bv                                4450 non-null float64
# Capex_Ps_Cf                       4450 non-null float64
# Capex_Sales                       4450 non-null float64
# Cash_Div_Cf                       4450 non-null float64
# Cash_Per_Share                    4450 non-null float64
# Cf_Sales                          4450 non-null float64
# Debtequity                        4450 non-null float64
# Div_Yld                           4450 non-null float64
# Dps                               4450 non-null float64
# Ebit_Bv                           4450 non-null float64
# Ebit_Noa                          4450 non-null float64
# Ebit_Oa                           4450 non-null float64
# Ebit_Ta                           4450 non-null float64
# Ebitda_Margin                     4450 non-null float64
# Eps                               4450 non-null float64
# Eps_Basic                         4450 non-null float64
# Eps_Basic_Gr                      4450 non-null float64
# Eps_Contin_Oper                   4450 non-null float64
# Eps_Dil                           4450 non-null float64
# Ev                                4450 non-null float64
# Ev_Ebitda                         4450 non-null float64
# Fa_Ci                             4450 non-null float64
# Fcf                               4450 non-null float64
# Fcf_Bv                            4450 non-null float64
# Fcf_Ce                            4450 non-null float64
# Fcf_Margin                        4450 non-null float64
# Fcf_Noa                           4450 non-null float64
# Fcf_Oa                            4450 non-null float64
# Fcf_Ta                            4450 non-null float64
# Fcf_Tbv                           4450 non-null float64
# Fcf_Toa                           4450 non-null float64
# Fcf_Yld                           4450 non-null float64
# Free_Ps_Cf                        4450 non-null float64
# Int_Rev                           4450 non-null float64
# Interest_Expense                  4450 non-null float64
# Mkt_Cap_12M_Usd                   4450 non-null float64
# Mkt_Cap_3M_Usd                    4450 non-null float64
# Mkt_Cap_6M_Usd                    4450 non-null float64
# Mom_11M_Usd                       4450 non-null float64
# Mom_5M_Usd                        4450 non-null float64
# Mom_Sharp_11M_Usd                 4450 non-null float64
# Mom_Sharp_5M_Usd                  4450 non-null float64
# Nd_Ebitda                         4450 non-null float64
# Net_Debt                          4450 non-null float64
# Net_Debt_Cf                       4450 non-null float64
# Net_Margin                        4450 non-null float64
# Netdebtyield                      4450 non-null float64
# Ni                                4450 non-null float64
# Ni_Avail_Margin                   4450 non-null float64
# Ni_Oa                             4450 non-null float64
# Ni_Toa                            4450 non-null float64
# Noa                               4450 non-null float64
# Oa                                4450 non-null float64
# Ocf                               4450 non-null float64
# Ocf_Bv                            4450 non-null float64
# Ocf_Ce                            4450 non-null float64
# Ocf_Margin                        4450 non-null float64
# Ocf_Noa                           4450 non-null float64
# Ocf_Oa                            4450 non-null float64
# Ocf_Ta                            4450 non-null float64
# Ocf_Tbv                           4450 non-null float64
# Ocf_Toa                           4450 non-null float64
# Op_Margin                         4450 non-null float64
# Op_Prt_Margin                     4450 non-null float64
# Oper_Ps_Net_Cf                    4450 non-null float64
# Pb                                4450 non-null float64
# Pe                                4450 non-null float64
# Ptx_Mgn                           4450 non-null float64
# Recurring_Earning_Total_Assets    4450 non-null float64
# Return_On_Capital                 4450 non-null float64
# Rev                               4450 non-null float64
# Roa                               4450 non-null float64
# Roc                               4450 non-null float64
# Roce                              4450 non-null float64
# Roe                               4450 non-null float64
# Sales_Ps                          4450 non-null float64
# Share_Turn_12M                    4450 non-null float64
# Share_Turn_3M                     4450 non-null float64
# Share_Turn_6M                     4450 non-null float64
# Ta                                4450 non-null float64
# Tev_Less_Mktcap                   4450 non-null float64
# Tot_Debt_Rev                      4450 non-null float64
# Total_Capital                     4450 non-null float64
# Total_Debt                        4450 non-null float64
# Total_Debt_Capital                4450 non-null float64
# Total_Liabilities_Total_Assets    4450 non-null float64
# Vol1Y_Usd                         4450 non-null float64
# Vol3Y_Usd                         4450 non-null float64
# R1M_Usd                           4450 non-null float64
# R3M_Usd                           4450 non-null float64
# R6M_Usd                           4450 non-null float64
# R12M_Usd                          4450 non-null float64
# dtypes: float64(97), int64(1), object(1)
# memory usage: 3.4+ MB

# %%
X= df.drop(['stock_id','date'], axis=1) # scaling the features will be automatically done.

# %%
model=pca(n_components=5, normalize=True)

# %%
results = model.fit_transform(X)
# Out:
# [pca] >Processing dataframe..
# [pca] >Normalizing input data per feature (zero mean and unit variance)..
# [pca] >The PCA reduction is performed on the [97] columns of the input dataframe.
# [pca] >Fitting using PCA..
# [pca] >Computing loadings and PCs..
# [pca] >Computing explained variance..
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[5]
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]

# %%
#results

# %%
loadings=results['loadings']
loadings
# Out:
#      Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  Asset_Turnover    Bb_Yld  \
# PC1      0.123418     0.126343     0.125503        0.020272  0.063947
# PC2      0.138670     0.130818     0.133819       -0.044864  0.013430
# PC3     -0.124841    -0.124347    -0.125028       -0.270337 -0.046423
# PC4      0.020008     0.016621     0.017208       -0.084316 -0.015866
# PC5     -0.145086    -0.163344    -0.157985        0.090041  0.002193
#
#            Bv  Capex_Ps_Cf  Capex_Sales  Cash_Div_Cf  Cash_Per_Share  ...  \
# PC1  0.011040     0.041722     0.022285     0.035080        0.127626  ...
# PC2 -0.048430     0.090063     0.068790    -0.033752       -0.044533  ...
# PC3  0.049457    -0.097444     0.015554     0.120505       -0.022217  ...
# PC4 -0.075286    -0.164699    -0.102311     0.012748        0.153058  ...
# PC5  0.083532     0.180394    -0.036942     0.076489        0.087069  ...
#
#      Total_Capital  Total_Debt  Total_Debt_Capital  \
# PC1       0.076032    0.070140            0.043927
# PC2       0.222852    0.240883            0.213707
# PC3       0.036238    0.033167            0.033519
# PC4       0.026351    0.043164            0.049610
# PC5       0.027948    0.024663            0.041025
#
#      Total_Liabilities_Total_Assets  Vol1Y_Usd  Vol3Y_Usd   R1M_Usd   R3M_Usd  \
# PC1                        0.045840  -0.090418  -0.095654 -0.004191 -0.006775
# PC2                        0.195219   0.020990   0.015851  0.004126  0.007243
# PC3                        0.085878  -0.167332  -0.165143  0.005037  0.009050
# PC4                        0.050242   0.063362   0.064437  0.044355  0.065488
# PC5                        0.070700   0.025710   0.003049  0.039446  0.059138
#
#       R6M_Usd  R12M_Usd
# PC1 -0.004689 -0.001792
# PC2  0.007869  0.001106
# PC3  0.018022  0.019287
# PC4  0.081798  0.055311
# PC5  0.066372  0.042994
#
# [5 rows x 97 columns]

# %%
scores=results['PC']
scores.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5
# 0  6.363602  6.173358 -2.505719 -0.046896 -3.548416
# 1  9.523135  2.507746  1.660606  0.326112 -5.300313
# 2  5.800236  1.898347 -2.195353  1.877733 -2.937242
# 3  0.715543  9.557593 -0.380252  3.213835 -1.973199
# 4  9.303851  7.762789 -2.299553 -0.555058 -0.338284

# %%
scores.shape
# Out:
# (4450, 5)

# %% [markdown]
# ---
# ## Scree plot

# %%
model.plot(figsize=(10,8))
plt.show()

# %% [markdown]
# ---
# ## Biplot
#
# Biplot displays both the PC scores and PC loadings. We will use the **pca.biplot_** method from the **pca** library.

# %%
import itertools

# %%
labels= np.array(list(itertools.repeat("No label", len(X))))

# %%
model.biplot(n_feat=3,  legend=False, figsize=(16,12), y= labels, label=False, cmap=None)
plt.show()
